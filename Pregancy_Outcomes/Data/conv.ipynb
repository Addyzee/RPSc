# %%
import pandas as pd
df = pd.read_excel('c:\\Users\\swift\\Documents\\GitHub\\RPSc\\Pregancy_Outcomes\\Data\\main_dataset.xlsx')
# Out:
# c:\Users\swift\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
df = df.iloc[0:200]
# Out:
#          id  country facility_coded referral_in  apgar_1  apgar_5  \
# 0    162230        2         HF0004           1      7.0      9.0
# 1    127964        2         HF0005         NaN      NaN      NaN
# 2    148113        2         HF0006           0      NaN      NaN
# 3     95858        1          HF014         NaN     10.0     10.0
# 4    206414        1          HF007         NaN      9.0     10.0
# ..      ...      ...            ...         ...      ...      ...
# 195  190769        1          HF019         NaN      NaN      NaN
# 196  193106        1          HF019         NaN      NaN      NaN
# 197  194642        1          HF019         NaN     10.0     10.0
# 198  194643        1          HF019         NaN      8.0      9.0
# 199  195612        1          HF019         NaN      0.0      0.0
#
#                sex baby_discharge_status  multiple  bba  ...     record_type  \
# 0             Male                   NaN       1.0    0  ...           Birth
# ...

# %%
df.to_csv('main_dataset_200.csv')
